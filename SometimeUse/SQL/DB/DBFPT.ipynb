-- %% [markdown]
-- # [DeFBT]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [DeFBT]    Script Date: 3/14/2023 9:22:04 AM ******/
CREATE DATABASE [DeFBT]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'DeThiThu', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\DeThiThu.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'DeThiThu_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\DeThiThu_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [DeFBT] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [DeFBT].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [DeFBT] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [DeFBT] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [DeFBT] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [DeFBT] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [DeFBT] SET ARITHABORT OFF 
GO
ALTER DATABASE [DeFBT] SET AUTO_CLOSE ON 
GO
ALTER DATABASE [DeFBT] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [DeFBT] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [DeFBT] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [DeFBT] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [DeFBT] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [DeFBT] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [DeFBT] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [DeFBT] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [DeFBT] SET  ENABLE_BROKER 
GO
ALTER DATABASE [DeFBT] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [DeFBT] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [DeFBT] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [DeFBT] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [DeFBT] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [DeFBT] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [DeFBT] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [DeFBT] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [DeFBT] SET  MULTI_USER 
GO
ALTER DATABASE [DeFBT] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [DeFBT] SET DB_CHAINING OFF 
GO
ALTER DATABASE [DeFBT] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [DeFBT] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [DeFBT] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [DeFBT] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [DeFBT] SET QUERY_STORE = ON
GO
ALTER DATABASE [DeFBT] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[DANGKYCUNGCAP]

-- %%
USE [DeFBT]
GO

-- %%
/****** Object:  Table [dbo].[DANGKYCUNGCAP]    Script Date: 3/14/2023 9:22:04 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[DANGKYCUNGCAP](
	[MaDKCC] [nvarchar](7) NOT NULL,
	[MaNhaCC] [nvarchar](8) NOT NULL,
	[MaLoaiDV] [nvarchar](6) NOT NULL,
	[DongXe] [nvarchar](15) NOT NULL,
	[MaMP] [nvarchar](5) NOT NULL,
	[NgayBatDauCungCap] [datetime] NOT NULL,
	[NgayKetThucCungCap] [datetime] NOT NULL,
	[SoLuongXeDangKy] [int] NULL,
 CONSTRAINT [PK_DANGKYCUNGCAP] PRIMARY KEY CLUSTERED 
(
	[MaDKCC] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[DONGXE]

-- %%
/****** Object:  Table [dbo].[DONGXE]    Script Date: 3/14/2023 9:22:04 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[DONGXE](
	[DongXe] [nvarchar](15) NOT NULL,
	[HangXe] [nvarchar](10) NOT NULL,
	[SoChoNgoi] [int] NOT NULL,
 CONSTRAINT [PK_DONGXE] PRIMARY KEY CLUSTERED 
(
	[DongXe] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[LOAIDICHVU]

-- %%
/****** Object:  Table [dbo].[LOAIDICHVU]    Script Date: 3/14/2023 9:22:04 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[LOAIDICHVU](
	[MaLoaiDV] [nvarchar](6) NOT NULL,
	[TenLoaiDV] [nvarchar](50) NOT NULL,
 CONSTRAINT [PK_LOAIDICHVU] PRIMARY KEY CLUSTERED 
(
	[MaLoaiDV] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[MUCPHI]

-- %%
/****** Object:  Table [dbo].[MUCPHI]    Script Date: 3/14/2023 9:22:04 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[MUCPHI](
	[MaMP] [nvarchar](5) NOT NULL,
	[DonGia] [nvarchar](7) NOT NULL,
	[MoTa] [nvarchar](30) NULL,
 CONSTRAINT [PK_MUCPHI] PRIMARY KEY CLUSTERED 
(
	[MaMP] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[NHACUNGCAP]

-- %%
/****** Object:  Table [dbo].[NHACUNGCAP]    Script Date: 3/14/2023 9:22:04 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[NHACUNGCAP](
	[MaNhaCC] [nvarchar](8) NOT NULL,
	[TenNhaCC] [nvarchar](50) NOT NULL,
	[DiaChi] [nvarchar](30) NOT NULL,
	[SoDT] [varchar](15) NULL,
	[MaSoThue] [nvarchar](15) NOT NULL,
 CONSTRAINT [PK_NHACUNGCAP] PRIMARY KEY CLUSTERED 
(
	[MaNhaCC] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [PK_DANGKYCUNGCAP_DongXe]

-- %%
ALTER TABLE [dbo].[DANGKYCUNGCAP]  WITH CHECK ADD  CONSTRAINT [PK_DANGKYCUNGCAP_DongXe] FOREIGN KEY([DongXe])
REFERENCES [dbo].[DONGXE] ([DongXe])
GO
ALTER TABLE [dbo].[DANGKYCUNGCAP] CHECK CONSTRAINT [PK_DANGKYCUNGCAP_DongXe]
GO

-- %% [markdown]
-- # [PK_DANGKYCUNGCAP_MaLoaiDV]

-- %%
ALTER TABLE [dbo].[DANGKYCUNGCAP]  WITH CHECK ADD  CONSTRAINT [PK_DANGKYCUNGCAP_MaLoaiDV] FOREIGN KEY([MaLoaiDV])
REFERENCES [dbo].[LOAIDICHVU] ([MaLoaiDV])
GO
ALTER TABLE [dbo].[DANGKYCUNGCAP] CHECK CONSTRAINT [PK_DANGKYCUNGCAP_MaLoaiDV]
GO

-- %% [markdown]
-- # [PK_DANGKYCUNGCAP_MaMP]

-- %%
ALTER TABLE [dbo].[DANGKYCUNGCAP]  WITH CHECK ADD  CONSTRAINT [PK_DANGKYCUNGCAP_MaMP] FOREIGN KEY([MaMP])
REFERENCES [dbo].[MUCPHI] ([MaMP])
GO
ALTER TABLE [dbo].[DANGKYCUNGCAP] CHECK CONSTRAINT [PK_DANGKYCUNGCAP_MaMP]
GO

-- %% [markdown]
-- # [PK_DANGKYCUNGCAP_MaNhaCC]

-- %%
ALTER TABLE [dbo].[DANGKYCUNGCAP]  WITH CHECK ADD  CONSTRAINT [PK_DANGKYCUNGCAP_MaNhaCC] FOREIGN KEY([MaNhaCC])
REFERENCES [dbo].[NHACUNGCAP] ([MaNhaCC])
GO
ALTER TABLE [dbo].[DANGKYCUNGCAP] CHECK CONSTRAINT [PK_DANGKYCUNGCAP_MaNhaCC]
GO

-- %% [markdown]
-- # [DeFBT]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [DeFBT] SET  READ_WRITE 
GO
